# %%
import pandas as pd 
import csv

# %%
budgets = pd.read_csv('zippedData/tn.movie_budgets.csv.gz', compression = 'gzip')
rt_info.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
tmdb_movies = pd.read_csv('zippedData/tmdb.movies.csv.gz', compression = 'gzip')
tmdb_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
# !ls zippedData | grep csv > file_list.txt
# !cat file_list.txt
# Out:
# bom.movie_gross.csv.gz
# imdb.name.basics.csv.gz
# imdb.title.akas.csv.gz
# imdb.title.basics.csv.gz
# imdb.title.crew.csv.gz
# imdb.title.principals.csv.gz
# imdb.title.ratings.csv.gz
# tmdb.movies.csv.gz
# tn.movie_budgets.csv.gz

# %%
file_dict['imdb.name.basics'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   nconst              606648 non-null  object
#  1   primary_name        606648 non-null  object
#  2   birth_year          82736 non-null   float64
#  3   death_year          6783 non-null    float64
#  4   primary_profession  555308 non-null  object
#  5   known_for_titles    576444 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB

# %%
with open ('file_list.txt', 'r') as f:
    csv_list= f.readlines()
file_dict = {}
for csv in csv_list:
    key='ZippedData/'+csv.strip()
    df_name=csv.strip()
    df_name=df_name.split('.csv.gz')[0]
    df=pd.read_csv(key, compression='gzip')
    file_dict[df_name] = df
file_dict.keys
# Out:
# <function dict.keys>

# %%
# with open ('file_list.txt', 'r') as f:
#     csv_list= f.readlines()
# file_dict = {}
# for csv in csv_list:
#     key='ZippedData/'+csv.strip()
#     df_name=csv.strip()
#     df_name=df_name.split('.csv.gz')[0]
#     df=pd.read_csv(key, compression='gzip')
#     file_dict[df_name] = df
# file_dict.keys

# %% [markdown]
# BEGIN FILE PREVIEWS ----------------------------------------------------------------------------------------------

# %%
len(file_dict['tn.movie_budgets'])
# Out:
# 5782

# %%
file_dict['bom.movie_gross'].head(1)
# Out:
#          title studio  domestic_gross foreign_gross  year
# 0  Toy Story 3     BV     415000000.0     652000000  2010

# %%
file_dict['tmdb.movies'].head(1)
# Out:
#    Unnamed: 0        genre_ids     id original_language  \
# 0           0  [12, 14, 10751]  12444                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788

# %%
# len(file_dict['imdb.title.ratings'])
len(pd.unique(file_dict['imdb.title.ratings']['tconst']))
file_dict['imdb.title.ratings'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
file_dict['imdb.title.principals'].head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
# file_dict['imdb.title.basics'].head(1)

len(file_dict['imdb.title.basics'])
# len(pd.unique(file_dict['imdb.title.basics']['tconst']))
# Out:
# 146144

# %%
file_dict['imdb.name.basics'].head(1)
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
#
#                           primary_profession  \
# 0  miscellaneous,production_manager,producer
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553

# %%
file_dict['imdb.title.akas'].head(10)

# len(file_dict['imdb.title.akas'])
# len(pd.unique(file_dict['imdb.title.akas']['tconst']))
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
# 5  tt0369610        15                           Jurassic World     GR
# 6  tt0369610        16                           Jurassic World     IT
# 7  tt0369610        17                            Jurski svijet     HR
# 8  tt0369610        18                             Olam ha'Yura     IL
# 9  tt0369610        19           Jurassic World: Mundo Jurásico     MX
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# ...

# %%
# movies - directors - writers

# file_dict['imdb.title.crew'].head(10)
file_dict['imdb.title.crew'].info()
# len(file_dict['imdb.title.crew'])
# len(pd.unique(file_dict['imdb.title.akas']['tconst']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB

# %%
name_and_id = file_dict['imdb.name.basics'][['nconst', 'primary_name']]

name_movie_job = file_dict['imdb.title.principals'].merge(name_and_id, how = 'left', on = 'nconst')
name_movie_job.columns
name_movie_job.head(10)
# name_movie_job.info()
len(pd.unique(name_movie_job['job']))
# Out:
# 2966

# %% [markdown]
# END FILE PREVIEWS -------------------------------------------------------------------------------------------------

# %%
file_dict['imdb.title.basics'].loc[file_dict['imdb.title.basics']['tconst'] == 'tt0063540']


# Pulling row based on value of a specific column
# Out:
#       tconst primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                genres
# 0  Action,Crime,Drama

# %%
file_dict['imdb.title.ratings'].head(1)
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31

# %%
# Merging title.basics and title.ratings on 'tconst'

basic_rating = file_dict['imdb.title.basics'].merge(file_dict['imdb.title.ratings'], how = 'left', on = 'tconst')




# len(pd.unique(basic_rating['genres']))
# basic_rating.info()

# len(basic_rating)
# basic_rating.columns
basic_rating.head()
# total len 140 k Missing 30k runtime and half of both average rating and numvotes
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0      77.0
# 1        2019            114.0       Biography,Drama            7.2      43.0
# 2        2018            122.0                 Drama            6.9    4517.0
# 3        2018              NaN          Comedy,Drama            6.1      13.0
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5     119.0

# %%
len(file_dict['bom.movie_gross'])
# Out:
# 3387

# %%
# # Rename title_id column in title.akas to 'tconst' for merging 
# file_dict['imdb.title.akas'].rename(columns = {'title_id':'tconst'}, inplace = True)
# # file_dict['imdb.title.akas'].head(1)

# # Merge attempt with 


# basic_rating_aka = basic_rating.merge(file_dict['imdb.title.akas'], how = 'left', on = 'tconst')
# # basic_rating_aka.info()
# # len(pd.unique(basic_rating_aka['tconst']))



# basic_rating_aka.head(15)

# %%
# Population review working 


file_dict['imdb.title.ratings'].head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
# CRITIC REVIEW WORKING 




rt_reviews = pd.read_csv('zippedData/rt.reviews.tsv.gz',sep = '\t', compression = 'gzip', encoding = 'latin-1' )
rt_review_nonull =rt_reviews.dropna()

# rt_reviews.info()
# len(pd.unique(rt_reviews['critic'])) #3497
# rt_reviews['critic'].value_counts()[:10] #outputs 10 top number of critic occurences
# rt_reviews.head()


# rt_review_nonull =rt_reviews.dropna()  #len ~30k

# len(pd.unique(rt_review_nonull['id']))
rt_review_nonull
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 6         3  Quickly grows repetitive and tiresome, meander...      C  rotten
# 7         3  Cronenberg is not a director to be daunted by ...    2/5  rotten
# 11        3  While not one of Cronenberg's stronger films, ...     B-   fresh
# 12        3  Robert Pattinson works mighty hard to make Cos...    2/4  rotten
# ...     ...                                                ...    ...     ...
# 54419  2000            Sleek, shallow, but frequently amusing.  2.5/4   fresh
# 54420  2000  The spaniel-eyed Jean Reno infuses Hubert with...    3/4   fresh
# 54421  2000  Manages to be somewhat well-acted, not badly a...  1.5/4  rotten
# 54422  2000  Arguably the best script that Besson has writt...  3.5/5   fresh
# 54424  2000  Dawdles and drags when it should pop; it doesn...  1.5/5  rotten
#
# ...

# %%
rt_movie_info = pd.read_csv('zippedData/rt.movie_info.tsv.gz',sep = '\t', compression = 'gzip', encoding = 'latin-1' )
rt_movie_info
# type(rt_movie_info['theater_date'])

rt_movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
# EXPLODE 

# rt_movie_info['directors'] = rt_movie_info['director'].str.split('|')
# rt_movie_info.drop(columns = 'director', inplace = True)
# rt_movie_info.explode('directors', inplace = True)

# %%
rt_review_clean = rt_review_nonull[['id', 'rating', 'critic']]
# rt_review_clean
rt_all_df = rt_review_clean.merge(rt_movie_info, how = 'inner', on = 'id')

# rt_all_df['rating_x'][:50]

# rt_all_df.info()
rt_all_df = rt_all_df.rename(mapper ={'rating_x':'critic_rating', 'rating_y': 'mpa_rating'}, axis = 'columns')
# rt_all_df['critic_rating'].value_counts()['']

rt_all_df
# Out:
#          id critic_rating          critic  \
# 0         3           3/5      PJ Nabarro
# 1         3             C  Eric D. Snider
# 2         3           2/5    Matt Kelemen
# 3         3            B-    Emanuel Levy
# 4         3           2/4  Christian Toto
# ...     ...           ...             ...
# 33983  2000         2.5/4    Gene Seymour
# 33984  2000           3/4    Megan Turner
# 33985  2000         1.5/4     Bob Strauss
# 33986  2000         3.5/5      Wade Major
# 33987  2000         1.5/5  Manohla Dargis
#
#                                                 synopsis mpa_rating  \
# 0      New York City, not-too-distant-future: Eric Pa...          R
# 1      New York City, not-too-distant-future: Eric Pa...          R
# 2      New York City, not-too-distant-future: Eric Pa...          R
# 3      New York City, not-too-distant-future: Eric Pa...          R
# 4      New York City, not-too-distant-future: Eric Pa...          R
# ...

# %%
def norm_ratings(rating):
    grades = {"A":10,"B":8,"C":6,"D":4,"F":2,"A+":10,"B+":9,"C+":7,"D+":5,\
              "F+":3,"A-":9,"B-":7,"C-":5,"D-":3,"F-":0, '3 1/2': 3.5, 'T': None}
    
    if rating in grades.keys():
        norm=grades[rating]
        return norm
    elif ('/') in rating:
        r = rating.split('/')
        norm = float(r[0])/float(r[1])*10
        return norm
    elif ('-') in rating and len(rating) > 2:
        r = rating.split('-')
        norm = float(r[0])/float(r[1])*10
        return norm
    else:
        norm = float(rating)
        return norm


        
#   rt_all_df['critic_rating'].replace(to_replace = rating, value = norm, inplace = True)
      
# rt_all_df['critic_rating'] = rt_all_df['critic_rating'].apply(norm_ratings)
# norm_ratings('B+')
#1-5
#1/4
#A-
    
#         denom = 10/float(r[1])
#         num = r[0] * denom
# for rating in rt_all_df['rating_x']:
# ,"A+":10,"B+":9,"C+":7,"D+":5,"F+":3,"A-":9,"B-":7,"C-":5,"D-":3,"F-":0
# for critic_rating in rt_all_df.iterrows():
rt_all_df.head(10)
# Out:
#    id  critic_rating           critic  \
# 0   3            6.0       PJ Nabarro
# 1   3            6.0   Eric D. Snider
# 2   3            4.0     Matt Kelemen
# 3   3            7.0     Emanuel Levy
# 4   3            5.0   Christian Toto
# 5   3            8.0     Robert Roten
# 6   3            7.5      Marty Mapes
# 7   3            6.0        Adam Ross
# 8   3            8.0    Patrick Kolan
# 9   3            8.0  Dennis Schwartz
#
#                                             synopsis mpa_rating  \
# 0  New York City, not-too-distant-future: Eric Pa...          R
# 1  New York City, not-too-distant-future: Eric Pa...          R
# 2  New York City, not-too-distant-future: Eric Pa...          R
# 3  New York City, not-too-distant-future: Eric Pa...          R
# 4  New York City, not-too-distant-future: Eric Pa...          R
# 5  New York City, not-too-distant-future: Eric Pa...          R
# 6  New York City, not-too-distant-future: Eric Pa...          R
# ...

# %%
basic_rating.head(1)
# Out:
#       tconst primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                genres  averagerating  numvotes
# 0  Action,Crime,Drama            7.0      77.0

# %%
file_dict['imdb.title.crew'].head(1)
# Out:
#       tconst  directors    writers
# 0  tt0285252  nm0899854  nm0899854

# %%
title_dir_writer = basic_rating.merge(file_dict['imdb.title.crew'], how = 'left', on = 'tconst')

title_dir_writer.head(1)
# Out:
#       tconst primary_title original_title  start_year  runtime_minutes  \
# 0  tt0063540     Sunghursh      Sunghursh        2013            175.0
#
#                genres  averagerating  numvotes  directors  \
# 0  Action,Crime,Drama            7.0      77.0  nm0712540
#
#                                    writers
# 0  nm0023551,nm1194313,nm0347899,nm1391276

# %%
# name_and_id.rename(mapper = {'nconst': 'directors'}, axis = 'columns', inplace = True)
name_and_id.head(1)
# Out:
#    directors       primary_name
# 0  nm0061671  Mary Ellen Bauder

# %%
# test = title_dir_writer.merge(name_and_id, how = 'left', on = 'directors')
movie_dir_name_id = test
len(movie_dir_name_id)
movie_dir_name_id.head()
name_and_id.head()
# Out:
#    directors       primary_name
# 0  nm0061671  Mary Ellen Bauder
# 1  nm0061865       Joseph Bauer
# 2  nm0062070         Bruce Baum
# 3  nm0062195       Axel Baumann
# 4  nm0062798        Pete Baxter

# %%
movie_dir_name_id.head(5)
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes  \
# 0        2013            175.0    Action,Crime,Drama            7.0      77.0
# 1        2019            114.0       Biography,Drama            7.2      43.0
# 2        2018            122.0                 Drama            6.9    4517.0
# 3        2018              NaN          Comedy,Drama            6.1      13.0
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5     119.0
#
# ...

# %%
rt_all_df.rename(mapper = {'director': 'directors'}, axis = 'columns', inplace = True)


len(rt_all_df)
df = rt_all_df['directors'].str.split('|')
df.head(10)
rt_all_df.tail()
# Out:
#          id  critic_rating          critic  \
# 33983  2000           6.25    Gene Seymour
# 33984  2000           7.50    Megan Turner
# 33985  2000           3.75     Bob Strauss
# 33986  2000           7.00      Wade Major
# 33987  2000           3.00  Manohla Dargis
#
#                                                 synopsis mpa_rating  \
# 33983  Suspended from the force, Paris cop Hubert is ...          R
# 33984  Suspended from the force, Paris cop Hubert is ...          R
# 33985  Suspended from the force, Paris cop Hubert is ...          R
# 33986  Suspended from the force, Paris cop Hubert is ...          R
# 33987  Suspended from the force, Paris cop Hubert is ...          R
#
#                                                    genre directors  \
# 33983  Action and Adventure|Art House and Internation...       NaN
# 33984  Action and Adventure|Art House and Internation...       NaN
# 33985  Action and Adventure|Art House and Internation...       NaN
# ...

# %% [markdown]
# Basic_rating columns
# ['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'averagerating', 'numvotes']
#
#
# name_movie_job columns
#
# ['tconst', 'ordering', 'nconst', 'category', 'job', 'characters',
#        'primary_name']
#
#
# Person name/id in name_movie_job did job for movie in basic_rating
# Will relate person in each job to high rating movie
#
# will then join basic_rating to revenue and imdb numbers to get top grossing
