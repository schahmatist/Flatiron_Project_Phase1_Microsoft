# %% [markdown]
# # Microsoft Movie Industry Recommendations
# # D.A. Consulting
#
# - Dmitriy Fisch
# - Austin Boring
#  <br>
# March , 2022

# %% [markdown]
# # Goals
# ### Insights gained through detailed analaysis of Movie Industry Data
#
# - Determine if the movie industry shows evidence of growth over time?
# - Determine which variables correlate most strongly with profitability?

# %% [markdown]
# # Outline
#
# - ### Industry Analysis
# - ### Categorical Focus

# %% [markdown]
# # Industry Trends

# %% [markdown]
# Industry Profit Over Time
#
# ![profit_by_year-2.png](attachment:profit_by_year-2.png)

# %% [markdown]
# ### Trend Conclusion
#
# - The movie industry shows consistent growth with no signs of trending negatively
#     - There is no evidence to suggest that Microsoft should be discouraged from entering the industry.

# %% [markdown]
# ## Focus Areas
#
# Having conducted analysis on a number of varibales relating to movies and their success, we have drawn conclusions concerning several considerable factors.

# %% [markdown]
# ![misc_profit_correlations-2.png](attachment:misc_profit_correlations-2.png)
#
# <sub><sup>Popularity is calculated considering vote count, frequency, favorites, activity over time</sup></sub>

# %% [markdown]
# ![avg_rating_correlations.png](attachment:avg_rating_correlations.png)

# %% [markdown]
# ![profit_by_genre-2.png](attachment:profit_by_genre-2.png)

# %% [markdown]
# ![optimal_movie_length-2.png](attachment:optimal_movie_length-2.png)

# %% [markdown]
# ## Summary
# - The Movie industry has proven to be consistently profitable, with stable growth over the past 30 years
# - All publicity is good publiciity, popularity correlates strongly with profitbaility
#     - Promotion of any kind will contribute to success
# - Most profitbale
#     - Genre : Adventure / Science Fiction
#     - Rating: Perfect ratings (9-10) are too niche to be extremely profitabled
#     - Length: Slightly more than 2 hours long
