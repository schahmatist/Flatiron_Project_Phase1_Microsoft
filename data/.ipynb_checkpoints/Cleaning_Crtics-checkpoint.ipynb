# %%
import pandas as pd 
import csv

# %%
with open ('file_list.txt', 'r') as f:
    csv_list= f.readlines()
file_dict = {}
for csv in csv_list:
    key='ZippedData/'+csv.strip()
    df_name=csv.strip()
    df_name=df_name.split('.csv.gz')[0]
    df=pd.read_csv(key, compression='gzip')
    file_dict[df_name] = df
file_dict.keys
# Out:
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# Input In [336], in <cell line: 4>()
#       6     df_name=csv.strip()
#       7     df_name=df_name.split('.csv.gz')[0]
# ----> 8     df=pd.read_csv(key, compression='gzip')
#       9     file_dict[df_name] = df
#      10 file_dict.keys
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py:686, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     633     engine_specified = False
#     635 kwds.update(
#     636     delimiter=delimiter,
#     637     engine=engine,
#    (...)
#     683     skip_blank_lines=skip_blank_lines,
#     684 )
# --> 686 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py:452, in _read(filepath_or_buffer, kwds)
#     449 _validate_names(kwds.get("names", None))
#     451 # Create the parser.
# --> 452 parser = TextFileReader(fp_or_buf, **kwds)
#     454 if chunksize or iterator:
#     455     return parser
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py:946, in TextFileReader.__init__(self, f, engine, **kwds)
#     943 if "has_index_names" in kwds:
#     944     self.options["has_index_names"] = kwds["has_index_names"]
# --> 946 self._make_engine(self.engine)
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py:1178, in TextFileReader._make_engine(self, engine)
#    1176 def _make_engine(self, engine="c"):
#    1177     if engine == "c":
# -> 1178         self._engine = CParserWrapper(self.f, **self.options)
#    1179     else:
#    1180         if engine == "python":
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py:2008, in CParserWrapper.__init__(self, src, **kwds)
#    2005 self.usecols, self.usecols_dtype = _validate_usecols_arg(kwds["usecols"])
#    2006 kwds["usecols"] = self.usecols
# -> 2008 self._reader = parsers.TextReader(src, **kwds)
#    2009 self.unnamed_cols = self._reader.unnamed_cols
#    2011 passed_names = self.names is None
#
# File pandas/_libs/parsers.pyx:537, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:711, in pandas._libs.parsers.TextReader._get_header()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:2034, in pandas._libs.parsers.raise_parser_error()
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/gzip.py:479, in _GzipReader.read(self, size)
#     475 if self._new_member:
#     476     # If the _new_member flag is set, we have to
#     477     # jump to the next member, if there is one.
#     478     self._init_read()
# --> 479     if not self._read_gzip_header():
#     480         self._size = self._pos
#     481         return b""
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/gzip.py:427, in _GzipReader._read_gzip_header(self)
#     424     return False
#     426 if magic != b'\037\213':
# --> 427     raise BadGzipFile('Not a gzipped file (%r)' % magic)
#     429 (method, flag,
#     430  self._last_mtime) = struct.unpack("<BBIxx", self._read_exact(8))
#     431 if method != 8:
#
# BadGzipFile: Not a gzipped file (b',i')

# %%
rt_reviews = pd.read_csv('zippedData/rt.reviews.tsv.gz',sep = '\t', compression = 'gzip', encoding = 'latin-1' )

rt_movie_info = pd.read_csv('zippedData/rt.movie_info.tsv.gz',sep = '\t', compression = 'gzip', encoding = 'latin-1' )

# %%
rt_reviews_info = rt_movie_info[['id', 'director', 'runtime', 'rating']]

rt_reviews_cleaned = rt_reviews[['id', 'rating', 'critic']]
rt_df = rt_reviews_info.merge(rt_reviews_cleaned, how = 'inner', on = 'id')

rt_df.head(1)
# Out:
#    id          director      runtime rating_x rating_y      critic
# 0   3  David Cronenberg  108 minutes        R      3/5  PJ Nabarro

# %%
# NORMALIZE RATINGS RATING>FLOAT

def norm_ratings(rating):
    grades = {"A":10,"B":8,"C":6,"D":4,"F":2,"A+":10,"B+":9,"C+":7,"D+":5,\
              "F+":3,"A-":9,"B-":7,"C-":5,"D-":3,"F-":0, '3 1/2': 3.5, 'T': None, 'N':None, 'R':None}
    
    if rating in grades.keys():
        norm=grades[rating]
        return norm
    elif ('/') in rating:
        r = rating.split('/')
        norm = float(r[0])/float(r[1])*10
        return norm
    elif ('-') in rating and len(rating) > 2:
        r = rating.split('-')
        norm = float(r[0])/float(r[1])*10
        return norm
    else:
        norm = float(rating)
        return norm

    
    
rt_df.dropna(subset=['rating_y'],inplace=True)    
rt_df['critic_rating'] = rt_df['rating_y'].apply(norm_ratings)

# %%
# CLEAN RUNTIMES FLOAT>INT

def clean_runtime(runtime):
    minutes = runtime.split()[0]
    return int(minutes) 


rt_df.dropna(subset=['runtime'],inplace=True)    
rt_df['runtime'] = rt_df['runtime'].apply(clean_runtime)
rt_df.drop(columns = 'rating_y', inplace = True)
rt_df.head()
# Out:
#     id          director  runtime rating_x          critic  critic_rating
# 0    3  David Cronenberg      108        R      PJ Nabarro            6.0
# 6    3  David Cronenberg      108        R  Eric D. Snider            6.0
# 7    3  David Cronenberg      108        R    Matt Kelemen            4.0
# 11   3  David Cronenberg      108        R    Emanuel Levy            7.0
# 12   3  David Cronenberg      108        R  Christian Toto            5.0

# %%
# ADDING DIRECTOR NAME ID TO RT_DF

name_key = file_dict['imdb.name.basics'][['nconst', 'primary_name']]




rt_df2 = rt_df.merge(name_key, left_on = 'director', right_on = 'primary_name')
rt_df2 = rt_df2.drop(columns = 'primary_name')

rt_df2.head()
# Out:
#    id          director  runtime rating_x          critic  critic_rating  \
# 0   3  David Cronenberg      108        R      PJ Nabarro            6.0
# 1   3  David Cronenberg      108        R  Eric D. Snider            6.0
# 2   3  David Cronenberg      108        R    Matt Kelemen            4.0
# 3   3  David Cronenberg      108        R    Emanuel Levy            7.0
# 4   3  David Cronenberg      108        R  Christian Toto            5.0
#
#       nconst
# 0  nm0000343
# 1  nm0000343
# 2  nm0000343
# 3  nm0000343
# 4  nm0000343

# %%
movie_director_code = file_dict['imdb.title.crew'][['tconst', 'directors']]
movie_director_code['director'] = movie_director_code['directors'].str.split(',')
movie_director_code.drop(columns = 'directors', inplace = True)
movie_director_code = movie_director_code.explode('director')

# %%
movie_id_names_time = file_dict['imdb.title.basics'][['tconst', 'primary_title', 'original_title', 'runtime_minutes']]
half_way_clean = movie_id_names_time.merge(movie_director_code, how = 'inner', on = 'tconst')
half_way_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169262 entries, 0 to 169261
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           169262 non-null  object
#  1   primary_title    169262 non-null  object
#  2   original_title   169240 non-null  object
#  3   runtime_minutes  133324 non-null  float64
#  4   director         163535 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 7.7+ MB

# %%
def float_conv(flt):
    integer = int(flt)
    return integer


half_way_clean.dropna(subset = ['runtime_minutes'], inplace = True)
half_way_clean['runtime_minutes'] = half_way_clean['runtime_minutes'].apply(float_conv)

# %%
# half_way_clean.head(1)
rt_df.head(1)
# Out:
#    id          director  runtime rating_x      critic  critic_rating
# 0   3  David Cronenberg      108        R  PJ Nabarro            6.0

# %%
# combined_df = rt_df.merge(half_way_clean, left_on = ['runtime', 'nconst'], right_on = ['runtime_minutes', 'director'])

# len(combined_df['id'].unique())
combined_df.head()
# Out:
#    id       director_x  runtime rating_x         critic  critic_rating  \
# 0  14  Taylor Hackford      117        R    Laura Hiros            6.0
# 1  14  Taylor Hackford      117        R  James Luxford            4.0
# 2  14  Taylor Hackford      117        R  Brian Orndorf            5.0
# 3  14  Taylor Hackford      117        R   Nick Schager            5.0
# 4  14  Taylor Hackford      117        R  Frank Swietek            5.0
#
#       nconst     tconst primary_title original_title  runtime_minutes  \
# 0  nm0000431  tt1125929    Love Ranch     Love Ranch              117
# 1  nm0000431  tt1125929    Love Ranch     Love Ranch              117
# 2  nm0000431  tt1125929    Love Ranch     Love Ranch              117
# 3  nm0000431  tt1125929    Love Ranch     Love Ranch              117
# 4  nm0000431  tt1125929    Love Ranch     Love Ranch              117
#
#   director_y
# 0  nm0000431
# 1  nm0000431
# 2  nm0000431
# 3  nm0000431
# 4  nm0000431

# %%
tester = combined_df.rename({'director_x': 'DirectorName', 'rating_x': "MPArating", 'nconst':'DirectorId'}, inplace = True)

combined_df
# tester.head()
# Out:
#         id       director_x  runtime rating_x          critic  critic_rating  \
# 0       14  Taylor Hackford      117        R     Laura Hiros            6.0
# 1       14  Taylor Hackford      117        R   James Luxford            4.0
# 2       14  Taylor Hackford      117        R   Brian Orndorf            5.0
# 3       14  Taylor Hackford      117        R    Nick Schager            5.0
# 4       14  Taylor Hackford      117        R   Frank Swietek            5.0
# ...    ...              ...      ...      ...             ...            ...
# 6697  1944    Michel Gondry      119    PG-13  Edward Douglas            8.5
# 6698  1944    Michel Gondry      119    PG-13     Matt Singer            6.0
# 6699  1944    Michel Gondry      119    PG-13  Perri Nemiroff            6.0
# 6700  1944    Michel Gondry      119    PG-13       Sam Bathe            6.0
# 6701  1944    Michel Gondry      119    PG-13      Nell Minow            7.0
#
#          nconst     tconst     primary_title    original_title  \
# 0     nm0000431  tt1125929        Love Ranch        Love Ranch
# 1     nm0000431  tt1125929        Love Ranch        Love Ranch
# 2     nm0000431  tt1125929        Love Ranch        Love Ranch
# 3     nm0000431  tt1125929        Love Ranch        Love Ranch
# 4     nm0000431  tt1125929        Love Ranch        Love Ranch
# ...         ...        ...               ...               ...
# 6697  nm0327273  tt0990407  The Green Hornet  The Green Hornet
# 6698  nm0327273  tt0990407  The Green Hornet  The Green Hornet
# 6699  nm0327273  tt0990407  The Green Hornet  The Green Hornet
# 6700  nm0327273  tt0990407  The Green Hornet  The Green Hornet
# 6701  nm0327273  tt0990407  The Green Hornet  The Green Hornet
#
#       runtime_minutes director_y
# 0                 117  nm0000431
# 1                 117  nm0000431
# 2                 117  nm0000431
# 3                 117  nm0000431
# 4                 117  nm0000431
# ...               ...        ...
# 6697              119  nm0327273
# 6698              119  nm0327273
# 6699              119  nm0327273
# 6700              119  nm0327273
# 6701              119  nm0327273
#
# [6702 rows x 12 columns]

# %%
tester = combined_df.merge(file_dict['imdb.title.ratings'], on = 'tconst')
# tester2 = head()
# len(tester['id'].unique())
tester.info()
tester.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6686 entries, 0 to 6685
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               6686 non-null   int64
#  1   director_x       6686 non-null   object
#  2   runtime          6686 non-null   int64
#  3   rating_x         6686 non-null   object
#  4   critic           6494 non-null   object
#  5   critic_rating    6683 non-null   float64
#  6   nconst           6686 non-null   object
#  7   tconst           6686 non-null   object
#  8   primary_title    6686 non-null   object
#  9   original_title   6686 non-null   object
#  10  runtime_minutes  6686 non-null   int64
#  11  director_y       6686 non-null   object
#  12  averagerating    6686 non-null   float64
#  13  numvotes         6686 non-null   int64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 783.5+ KB
#    id       director_x  runtime rating_x         critic  critic_rating  \
# 0  14  Taylor Hackford      117        R    Laura Hiros            6.0
# 1  14  Taylor Hackford      117        R  James Luxford            4.0
# 2  14  Taylor Hackford      117        R  Brian Orndorf            5.0
# 3  14  Taylor Hackford      117        R   Nick Schager            5.0
# 4  14  Taylor Hackford      117        R  Frank Swietek            5.0
#
#       nconst     tconst primary_title original_title  runtime_minutes  \
# 0  nm0000431  tt1125929    Love Ranch     Love Ranch              117
# 1  nm0000431  tt1125929    Love Ranch     Love Ranch              117
# 2  nm0000431  tt1125929    Love Ranch     Love Ranch              117
# 3  nm0000431  tt1125929    Love Ranch     Love Ranch              117
# 4  nm0000431  tt1125929    Love Ranch     Love Ranch              117
#
#   director_y  averagerating  numvotes
# 0  nm0000431            5.6      2742
# 1  nm0000431            5.6      2742
# 2  nm0000431            5.6      2742
# 3  nm0000431            5.6      2742
# 4  nm0000431            5.6      2742

# %%
full_gross = pd.read_csv('tmdb_imdb_gross_full.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [350], in <cell line: 1>()
# ----> 1 full_gross = pd.read_csv('tmdb_imdb_gross_full.csv')
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py:686, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     633     engine_specified = False
#     635 kwds.update(
#     636     delimiter=delimiter,
#     637     engine=engine,
#    (...)
#     683     skip_blank_lines=skip_blank_lines,
#     684 )
# --> 686 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py:452, in _read(filepath_or_buffer, kwds)
#     449 _validate_names(kwds.get("names", None))
#     451 # Create the parser.
# --> 452 parser = TextFileReader(fp_or_buf, **kwds)
#     454 if chunksize or iterator:
#     455     return parser
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py:946, in TextFileReader.__init__(self, f, engine, **kwds)
#     943 if "has_index_names" in kwds:
#     944     self.options["has_index_names"] = kwds["has_index_names"]
# --> 946 self._make_engine(self.engine)
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py:1178, in TextFileReader._make_engine(self, engine)
#    1176 def _make_engine(self, engine="c"):
#    1177     if engine == "c":
# -> 1178         self._engine = CParserWrapper(self.f, **self.options)
#    1179     else:
#    1180         if engine == "python":
#
# File ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/parsers.py:2008, in CParserWrapper.__init__(self, src, **kwds)
#    2005 self.usecols, self.usecols_dtype = _validate_usecols_arg(kwds["usecols"])
#    2006 kwds["usecols"] = self.usecols
# -> 2008 self._reader = parsers.TextReader(src, **kwds)
#    2009 self.unnamed_cols = self._reader.unnamed_cols
#    2011 passed_names = self.names is None
#
# File pandas/_libs/parsers.pyx:382, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:674, in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tmdb_imdb_gross_full.csv'
